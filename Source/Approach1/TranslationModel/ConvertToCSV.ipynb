# %%
import pandas as pd
import numpy as np

# %%
inputfile = 'Result.actual.ti.final'

# %%
data = pd.read_csv(inputfile, sep = ' ', encoding = 'utf-8')

# %%
data
# Out:
#             VN           EN          Prob
# 0           từ          NaN  1.855100e-04
# 1           đã          NaN  3.410760e-01
# 2         được          NaN  6.164400e-01
# 3          vào          NaN  6.429840e-02
# 4            .          NaN  4.933750e-06
# 5          Một          NaN  4.567830e-05
# 6          mọi   predispose  4.317740e-04
# 7        người          NaN  2.559970e-01
# 8         mình        quest  8.604940e-05
# 9          làm          NaN  2.823520e-01
# 10        việc          NaN  1.832150e-01
# 11        cùng          NaN  2.812060e-05
# 12         của          NaN  9.071680e-01
# 13           ,          NaN  1.168280e-01
# 14          có          NaN  7.137170e-01
# 15         đều          NaN  2.381600e-04
# 16         đến          NaN  1.327430e-01
# 17         lụt       floods  3.113460e-01
# 18         các          NaN  1.763080e-01
# 19       trong          NaN  5.753050e-02
# 20          và          NaN  7.745190e-04
# 21        chọn          NaN  1.015820e-03
# 22        ngày          NaN  1.240370e-03
# 23         một          NaN  5.797810e-02
# 24       nhiều          NaN  1.224570e-05
# 25       không          NaN  9.732730e-02
# 26         lại          NaN  2.257900e-01
# 27         với          NaN  2.312040e-01
# 28         mới          NaN  1.151810e-02
# 29          sẽ          NaN  5.987150e-03
# ...        ...          ...           ...
# 153582     chế         1283  1.649090e-03
# 153583    chộp     grabbing  2.774320e-02
# 153584     cầu    commenced  7.200120e-04
# 153585     tới   Huntington  2.609310e-04
# 153586    lệnh      embargo  1.963540e-02
# 153587     dồn      Honours  3.117520e-02
# 153588     nhà       boasts  5.216080e-04
# 153589     gói      packers  5.503290e-03
# 153590      ta   predispose  9.706200e-07
# 153591      vỡ       ripped  3.481420e-03
# 153592   KHÔNG          YOU  1.984640e-01
# 153593    nhân      packers  3.557640e-04
# 153594    rách       ripped  2.038140e-02
# 153595     bắt    commenced  9.302080e-04
# 153596     nhà  centralized  2.310340e-04
# 153597      ra       boasts  1.196670e-04
# 153598    bằng        quest  1.100630e-04
# 153599    đóng      packers  1.157490e-03
# 153600      dỡ      embargo  1.398080e-01
# 153601    viên      packers  3.977700e-04
# 153602     nên       scheme  6.178040e-04
# 153603  thường       boasts  6.593280e-04
# 153604    thật       boasts  4.348050e-04
# 153605     rơi        plane  4.153920e-03
# 153606   trung  centralized  1.704980e-03
# 153607   Khánh        Trung  1.030840e-05
# 153608      để        quest  1.766750e-05
# 153609   lượng      packers  9.115200e-04
# 153610     bay        quest  8.162130e-04
# 153611     lên        quest  1.012280e-04
#
# [153612 rows x 3 columns]

# %%
result = data[(data.VN == 'lên') & (data.EN == 'quest')].Prob

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
tmp = result.values

# %%
type(tmp)
# Out:
# numpy.ndarray

# %%
len(tmp)
# Out:
# 1
